# %% [markdown]
# # Final Project - Analzying NJ Data
# ## Tomer Solomon
#
# This project is analyzing data from the NY Private Well Testing Act. In essence, this act requires NJ landowners as well as buyers/sellers of NJ property to disclose the quality of the water, and I am interested in seeing how Arsenic values have changed over time as well as which counties in NJ are most problematic when it comes to having arsenic in their water data. Hope you enjoy my project!
#
# The link to the data can be found here: http://njdep.maps.arcgis.com/apps/MapSeries/index.html?appid=826ec9fae77543caa582a787d5f088e7

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from scipy import stats

# %%
doc = 'ArsenicAllSamples_thruMar2014_for_BrianMailloux_Fe_Mn_GridID.csv'
data = pd.read_csv(doc,index_col='SAMPLE_DATE',parse_dates=['SAMPLE_DATE'])

# %%
data.head()
# Out:
#              DATA_SUBMISSION_ID  LOCATION_ID         MUNI_NAME COUNTY_NAME  \
# SAMPLE_DATE
# 2002-09-18                   10           10  HILLSBOROUGH TWP    SOMERSET
# 2008-03-24               139584           10  HILLSBOROUGH TWP    SOMERSET
# 2012-08-10               264009           10  HILLSBOROUGH TWP    SOMERSET
# 2002-09-03                   12           12      FRANKLIN TWP    SOMERSET
# 2002-09-06                   13           13  WEST MILFORD TWP     PASSAIC
#
#                COLLECTION_PT_DESC                             AnalyticLabName  \
# SAMPLE_DATE
# 2002-09-18       Before Treatment                                     QC INC.
# 2008-03-24   Alternative Location                                     QC INC.
# 2012-08-10           Bathroom Tap  AGRA ENVIRONMENTAL AND LABORATORY SERVICES
# 2002-09-03       Before Treatment                                     QC INC.
# 2002-09-06       Before Treatment                                     QC INC.
#
#             ANALYTIC_METHOD AS_QUALIFIER  AS_RESULT_VALUE AS_RESULT_UNIT  \
# SAMPLE_DATE
# 2002-09-18          SM3113B          NaN             3.40           ug/l
# 2008-03-24          SM3113B          NaN             5.20           ug/l
# 2012-08-10          SM3113B          NaN             4.57           ug/l
# 2002-09-03          SM3113B            <             2.00           ug/l
# 2002-09-06          SM3113B          NaN             2.20           ug/l
#
#                ...      FE_RESULT_UNIT FE_REPORTING_DETECTION_LIMIT  \
# SAMPLE_DATE    ...
# 2002-09-18     ...                mg/l                         0.03
# 2008-03-24     ...                mg/l                         0.03
# 2012-08-10     ...                mg/l                         0.10
# 2002-09-03     ...                mg/l                         0.03
# 2002-09-06     ...                mg/l                         0.03
#
#             FE_CHEMICAL_NAME  MN_QUALIFIER MN_RESULT_VALUE  MN_RESULT_UNIT  \
# SAMPLE_DATE
# 2002-09-18              Iron             <            0.01            mg/l
# 2008-03-24              Iron             <            0.01            mg/l
# 2012-08-10              Iron             <            0.03            mg/l
# 2002-09-03              Iron             <            0.01            mg/l
# 2002-09-06              Iron             <            0.01            mg/l
#
#             MN_REPORTING_DETECTION_LIMIT MN_CHEMICAL_NAME  PH_RESULT_VALUE  \
# SAMPLE_DATE
# 2002-09-18                          0.01        Manganese             7.33
# 2008-03-24                          0.01        Manganese             7.06
# 2012-08-10                          0.03        Manganese             7.32
# 2002-09-03                          0.01        Manganese             7.30
# 2002-09-06                          0.01        Manganese             7.06
#
#             GRID_2M_ID
# SAMPLE_DATE
# 2002-09-18        1183
# 2008-03-24        1183
# 2012-08-10        1183
# 2002-09-03        1181
# 2002-09-06        1481
#
# [5 rows x 24 columns]

# %%
fig,ax = plt.subplots()
data['AS_RESULT_VALUE'].plot()
ax.set_title('Arsenic Values over Time')
plt.xlabel('Date')
plt.ylabel('ug/l')

# %%
data.AS_RESULT_VALUE['2011':'2013'].plot()

# %%
#not analyzing this
data['FE_RESULT_VALUE'].plot()

# %%
#not analyzing this
data['MN_RESULT_VALUE'].plot()

# %%
fig,ax=plt.subplots()
props=dict(boxstyle='round',facecolor='white',alpha=0.5)


x = data.AS_RESULT_VALUE.resample('A',how=np.mean).index.year
y = data.AS_RESULT_VALUE.resample('A',how=np.mean)

#calculate statistics
results=stats.linregress(x,y)
ax.plot(x,results[0]*x+results[1])
textstr='m={:>12.3f}\nb ={:>10.3f}\n$r^2$={:>12.3f}\np ={:>12.3f}'.format(results[0],results[1],results[2]**2,results[3])
ax.text(0.75,0.95,textstr,transform=ax.transAxes,fontsize=10,verticalalignment='top',bbox=props)
ax.scatter(x,y)

ax.set_title('Average Arsenic Value per Year')
plt.xlabel('Date')
plt.ylabel('ug/l')

#old method
#data['AS_RESULT_VALUE'].resample('A',how='mean').plot()#marker='8',color='r',linestyle='none')
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %%
# for grids

for locat, df_group in data.groupby('GRID_2M_ID'):
    if df_group.AS_RESULT_VALUE.count() > 300:
        print 'location',locat
        print "mean AS value", df_group.AS_RESULT_VALUE.mean()
        print "count", df_group.AS_RESULT_VALUE.count()
        #print df_group
        fig,ax=plt.subplots()
        df_group.AS_RESULT_VALUE.plot()
        ax.set_title('{}'.format(locat))
# Out:
# location 969
# mean AS value 3.27722796353
# count 329
# location 970
# mean AS value 3.1848583815
# count 346
# location 1617
# mean AS value 4.39498543046
# count 755
# location 1848
# mean AS value 5.05296511628
# count 344
# location 1897
# mean AS value 3.97613989637
# count 386
# location 1989
# mean AS value 5.33018327974
# count 311
# location 1990
# mean AS value 5.39513926499
# count 517

# %%
#for grids

location_grid = []
mean_grid = []
for locat, df_group in data.groupby('GRID_2M_ID'):
    if df_group.AS_RESULT_VALUE.count() > 300:
        location_grid.append(locat)
        mean_grid.append(df_group.AS_RESULT_VALUE.mean())
        
y_position = np.arange(len(location_grid))

 
plt.barh(y_position, mean_grid, align='center', color = 'r', alpha=0.6,label="test")
plt.yticks(y_position, location_grid)
plt.ylabel('Grids')
plt.xlabel('Mean')

plt.title('Arsenic Means from 2002 to 2013 of Different Grids')
 
plt.show()
